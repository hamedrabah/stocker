# %% [markdown]
# Gathering Stock Data

# %%
import quandl
quandl.ApiConfig.api_key = "8-ezH_HnckMYzyxyVQgr"
import datetime as dt
import matplotlib.pyplot as plt

mydata = quandl.get_table('ZACKS/FC', ticker='AAPL', paginate=True)
mydata["emp_cnt"].plot()
plt.show()

# %%
from stocker import Stocker

# %%
microsoft = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-23.

# %%
stock_history = microsoft.stock
microsoft.plot_stock()
# Out:
# Maximum Adj. Close = 96.77 on 2018-03-12.
# Minimum Adj. Close = 0.06 on 1986-03-24.
# Current Adj. Close = 87.18 on 2018-03-23.

# %%
microsoft.plot_stock(start_date = '2018-01-03',  stats = ['Daily Change', 'Adj. Volume'],
plot_type='pct')
# Out:
# Maximum Daily Change = 4.44 on 2018-02-06.
# Minimum Daily Change = -4.82 on 2018-02-08.
# Current Daily Change = -2.32 on 2018-03-23.
#
# Maximum Adj. Volume = 66157030.00 on 2018-02-06.
# Minimum Adj. Volume = 16529868.00 on 2018-01-11.
# Current Adj. Volume = 42159397.00 on 2018-03-23.

# %%
microsoft.buy_and_hold(start_date='1986-03-13', 
                       end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $8829.11

# %%
microsoft.changepoint_date_analysis(search = 'xbox')
# Out:
# /anaconda/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#  Top Related Queries:
#
#              query  value
# 0         xbox one    100
# 1         xbox 360     62
# 2       xbox games     15
# 3        xbox live     15
# 4  xbox controller     11
#
#  Rising Related Queries:
#
#            query  value
# 0      pubg xbox  39750
# 1           pubg  39400
# 2   ark xbox one  35600
# 3        fifa 17  24750
# 4  rocket league  23950
# /Users/Hamed/Desktop/stocker/stocker.py:789: FutureWarning:
# .resample() is now a deferred operation
# You called reset_index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
#   trends = trends.reset_index(level=0)

# %%
model, future = microsoft.create_prophet_model(days=180)
# Out:
# /anaconda/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Price on 2018-09-19 = $105.74

# %%
techStocks = ["AAPL","MSFT","AMZN","NVDA"]

# %%
for stock in techStocks:
    stocks = Stocker(stock)
    model, future = stocks.create_prophet_model(days=180)
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 to 2018-03-23.
# /anaconda/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Price on 2018-09-19 = $196.83
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-23.
# Predicted Price on 2018-09-19 = $105.74
# AMZN Stocker Initialized. Data covers 1997-05-16 to 2018-03-23.
# Predicted Price on 2018-09-19 = $1999.30
# NVDA Stocker Initialized. Data covers 1999-01-22 to 2018-03-23.
# Predicted Price on 2018-09-19 = $308.97
